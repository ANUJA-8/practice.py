# %%
#1 1. Convert a string to uppercase using a method.
str="python"
print(str.upper())
# Out:
# PYTHON

# %%
#1 2. Convert a string to lowercase using a method.
print("PYTHON".lower())
# Out:
# python

# %%
#1 3. Remove spaces from both ends of a string.
print("  python  ".strip())
# Out:
# python

# %%
# 1 4. Count how many times a word appears in a string.
st="code good learn good"
print(st.count("good"))
# Out:
# 2

# %%
# 1 5. Replace one word with another in a string.
t="eat good live good"
print(t.replace("good","food"))
# Out:
# eat food live food

# %%
# 1 6. Check if a string contains only alphabets.
s="men has two legs 1- 2"
sp="men has two legs 1"
sp1="menhastwolegs1"
print(s.isalpha())
print(sp.isalnum()) #as this string contains space it is alphanum + spaces
print(sp1.isalnum()) #should give true
# Out:
# False
# False
# True

# %%
# 1 7. Check if a string contains only digits.
sd="34"
print(sd.isdigit())
# Out:
# True

# %%
# 1 8. Split a string into words.  
spp="every one has brain"
print(spp.split())
# Out:
# ['every', 'one', 'has', 'brain']

# %%
# 1 9. Join a list of words into a string.
j=('every', 'one', 'has', 'brain')
print(" ".join(j))  #at join we cannot take "j.join" becaous we have to pass the attribute value inside the bracket
# pt=" ".join(j)
# print(pt)
# Out:
# every one has brain

# %%
# 1 10. Find the position of a word in a string. 
str="man has brain"
print(str.rindex("has"))
print(str.split().index("has")+1)  #+ 1 for human value count
# Out:
# 4
# 2

# %%
# 1 11. Check whether a string starts with a given word.
se="Man has bike"
print(se.startswith("Man"))
print(se.startswith("Mn"))
# Out:
# False

# %%
#EXTRA
# 1 11. Check whether a string starts with a given word.  #print "Yes" or "no" for the result
se="Man has bike"  #you can check by taking "Mn", "pen" concludes if its checking only starting alphabet or whole word
# p=se.startswith("Man")
if se.startswith("Man"):
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
# 1 12. Check whether a string ends with a given word.
se="sam karlo"
print(se.endswith("karlo"))
# Out:
# True

# %%
# 1 13. Convert the first letter of a string to uppercase.
str="megha vasudev"
print(str.capitalize())
# Out:
# Megha vasudev

# %%
# 1 14. Convert a string into title case.
str="title case"
print(str.title())
# Out:
# Title Case

# %%
# 1 15. Count total characters in a string.
str="total char"
print(len(str))
# Out:
# 10

# %%
# 1 16. Remove all spaces from a string.
print(str.replace(" ",""))
# Out:
# totalchar

# %%
# 1 17. Swap uppercase letters to lowercase and vice versa. 
p="Python sWap up letters TO LOWER vice vers"
print(p.swapcase())
print(p.isupper())
# Out:
# pYTHON SwAP UP LETTERS to lower VICE VERS
# False

# %%
# 1 18. Check if a string is in uppercase.
pc="PYTHON IS"
print(pc.isupper())
# Out:
# True

# %%
# 1 19. Check if a string is in lowercase.
pc="python is"
pt="Pyhton is"
print(pc.islower())
print(pt.islower())
# Out:
# True
# False

# %%
# 1 20. Check if a string is alphanumeric.
pa="wer3"
pa1="t"
s="34"
print(pa.isnumeric())
print(pa.isalpha())
print(pa1.isalnum()) #there is no numeric value still why it is showing "True"
print(s.isalnum()) #there is no numeric value still why it is showing "True"
# Out:
# False
# False
# True
# False
# False
# True
# True

# %%
# 1 21. Split a string using a comma.
ma="ravet is near to pimpri"
print(ma.split())
# Out:
# ['ravet', 'is', 'near', 'to', 'pimpri']

# %%
# 1 22. Remove leading spaces from a string.
# lstrip()	Removes whitespace only from the start.
# strip()	Removes whitespace from both start and end.
# re.sub()	Uses patterns (regex) for precise leading space removal.
# dedent()	Removes common leading whitespace from every line in a block.

space="  ear and nose  "
print(space.strip())
# Out:
# ear and nose

# %%
# 1 23. Remove trailing spaces from a string. a space character at the end of a file or folder name
import textwrap
space="im here to " \
"help you,\nas a master"
print(space)
print(textwrap.dedent(space))
# Out:
# im here to help you,
# as a master
# im here to help you,
# as a master

# %%
# 1 24. Center a string with * symbol.
st="parvati"
print(st.center(len(st)+2,"*"))
# Out:
# *parvati*

# %%
# 1 25. Count number of vowels in a string using methods.
st="AReIFDSU"
vo=("a","e","i","o","u","A","E","I","O","U")
print(st.count(for s in st in vo))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 3
#       1 # 1 25. Count number of vowels in a string using methods.
#       2 st="AREIFDSU"
# ----> 3 print(st.count(("a","E","i","o","u"),0,len(st)))
#
# TypeError: must be str, not tuple

# %%
# 1 26. Check if a word exists in a string.
r="str is this"
if "is" in r:  #you can direct write a string here in "quote"
    print("Yes")
# Out:
# Yes

# %%
# 1 27. Convert a string into a list of characters. #done before

# %%
# 1 28. Repeat a string three times.
st="sam"
print(3*(st+" "))
print(3*(st+"\n"))
# Out:
# sam sam sam
# sam
# sam
# sam

# %%
# 1 29. Check whether a string is empty.
dt=" "
if not dt:   #to check the value in string use not
    print("string is empty")
else:
    print("Not null")
# Out:
# Not null

# %%
# 1 30. Reverse a string using methods.
s="namendra hr"
print(s[::-1])  #as [start:end:step] start=end point if the step is "-ve"  and end=start
# Out:
# rh ardneman

# %%
# 1 31. Add an element to a list.
l=["w",'r',6]
print(l.append('3'))
print(l)
# Out:
# None
# ['w', 'r', 6, '3']

# %%
# 1 32. Remove the last element from a list.
r=l.pop()
print(l)
# Out:
# ['w', 'r', 6]

# %%
# 1 33. Remove a specific element from a list.
s=l.remove('r')
print(l)
# Out:
# ['w', 6]

# %%
# 1 34. Insert an element at index 2 in a list.
i=l.insert(2,"Radha")
print(i)   ###Why we don't call "i" as we are assigning new value in it as string
# Out:
# ['w', 6, 'Radha']

# %%
# 1 35. Sort a list in ascending order.
l=[3,5,2,7,1,8,40]
# s=l.sort()
print(l.sort(),l)
# Out:
# None [1, 2, 3, 5, 7, 8, 40]

# %%
# 1 36. Sort a list in descending order.
d=l.sort()
print(l[::-1])
# Out:
# [40, 8, 7, 5, 3, 2, 1]

# %%
# 1 37. Reverse a list.  ###WHY IT is showing none to reverse
l=[2,4,6]
print(l[::-1])
print(l.reverse())
# Out:
# [6, 4, 2]
# None

# %%
# 1 38. Copy a list.  ###Does copy gives two list 
l=[2,'r',4,6]
c=l.copy()
print(l)
# Out:
# [2, 'r', 4, 6]

# %%
# 1 39. Count how many times an element appears in a list.
r=[2, 'r', 4, 6,'r',"p","r"]
print(r.count('r'))
# Out:
# 3

# %%
# 1 40. Find the index of an element in a list.
r=[2, 'r', 4, 6,'r',"p","r"]
print(r.index('p',0,len(r)))
# Out:
# 5

# %%
# 1 41. Clear all elements from a list.
r=[2, 'r', 4, 6,'r',"p","r"]
c=r.clear()
print(r)
# Out:
# []

# %%
# 1 42. Merge two lists.
l1=['r',"p","r"]
r=[2, 'r', 4, 6]
print(l1+r)
# Out:
# ['r', 'p', 'r', 2, 'r', 4, 6]

# %%
# 1 43. Remove an element using index.
r=[2, 'r', 4, 6]
t=r.pop(1)
print(r)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[171], line 3
#       1 # 1 43. Remove an element using index.
#       2 r=[2, 'r', 4, 6]
# ----> 3 p=r.remove(1)
#       4 print(r)
#
# ValueError: list.remove(x): x not in list

# %%
# 1 44. Print length of a list.
r=[2, 'r', 4, 6]
print(len(r))
# Out:
# 4

# %%
# 1 45. Check if an element exists in a list.
r=[2, 'r', 4, 6]
if 'r' in r:
    print("yes")
else:
    print("No")
# Out:
# yes

# %%
# 1 46. Remove duplicate elements from a list.
r=[2, 'r', 4, 6,'r',"r",3,'y',2]
d=list(set(r))
print(d)
# Out:
# [2, 3, 4, 'y', 6, 'r']

# %%
# 1 47. Add multiple elements to a list.
d=[3,'e',5]
d.extend([3,'r',"t"])
print(d)
# Out:
# [3, 'e', 5, 3, 'r', 't']

# %%
# 1 48. Print the last element of a list.
print(d[-1])
# Out:
# t

# %%
# 1 49. Print the first element of a list.
print(d[0])
# Out:
# 3

# %%
# 1 50. Sort a list without changing the original list.
p=[2,4,35,6,7,]
p.sort()
print(p)
# Out:
# [2, 4, 6, 7, 35]

# %%
# 1 51. Remove all occurrences of an element from a list.
m=[2, 4, 6, 7, 35,4,6,4]
m.remove(4)
print(m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[197], line 3
#       1 # 1 51. Remove all occurrences of an element from a list.
#       2 m=[2, 4, 6, 7, 35,4,6,4]
# ----> 3 m.clear(4)
#       4 print(m)
#
# TypeError: list.clear() takes no arguments (1 given)

# %%
# 1 52. Convert a string into a list. ##Done in st

# %%
# 1 53. Find maximum element in a list.
m=[2, 4, 6, 7, 35,4,6,4]
print(max(m))
# Out:
# 35

# %%
# 1 54. Find minimum element in a list.
print(min(m))
# Out:
# 2

# %%
# 1 55. Find sum of list elements.
print(sum(m))
# Out:
# 68

# %%
# 1 56. Print even numbers from a list.
m=[2, 4, 6, 7, 35,4,6,4]
e=[i for i in m if i%2==0]
print(e)
# Out:
# [2, 4, 6, 4, 6, 4]

# %%
# 1 57. Print odd numbers from a list.
m=[2, 4, 6, 7, 35,4,6,4]
e=[i for i in m if i%2!=0]
print(e)
# Out:
# [7, 35]

# %%
m=[2, 4, 6, 7, 35,4,6,4]
print(m.count(4))
print(len(m))
# Out:
# 3
# 8

# %%
# 1 59. Replace an element in a list.
m[2]="Sangu"
print(m)
# Out:
# [2, 4, 'Sangu', 7, 35, 4, 6, 4]

# %%
# 1 60. Check if a list is empty.  ###keep in mind
m=[2, 4, 6, 7, 35,4,6,4]
if not m:
    print("list is empty")
else:
    print("List is not empty")
# Out:
# List is not empty

# %%
# 1 61. Print all keys of a dictionary.
di={"Name":"Ana","Age":28}
print(di.keys())
# Out:
# dict_keys(['Name', 'Age'])

# %%
# 1 62. Print all values of a dictionary.
di={"Name":"Ana","Age":28}
print(di.values())
# Out:
# dict_values(['Ana', 28])

# %%
# 1 63. Print all key-value pairs of a dictionary.
print(di)
# Out:
# {'Name': 'Ana', 'Age': 28}

# %%
# 1 64. Get value of a key from dictionary.
value=di["Name"]
print(value)
# Out:
# Ana

# %%
# 1 65. Remove a key from a dictionary.
di={'Name': 'Ana', 'Age': 28}
del di["Name"]
print(di)
# Out:
# {'Age': 28}

# %%
# 1 66. Clear a dictionary.
cl=di.clear()
print(di)
# Out:
# {}

# %%
# 1 67. Copy a dictionary.
e={"Name":"Anu","Weight":56}
c=e.copy()
print(c)
# Out:
# {'Name': 'Anu', 'Weight': 56}

# %%
# 1 68. Update a dictionary with new values.
e={"Name":"Anu","Weight":56}
e.update({"Name":"Sadhna"})  # we can update by using update method
e["Weight"]=64               # we can update by keys by giving a value
print(e)
# Out:
# {'Name': 'Sadhna', 'Weight': 64}

# %%
# 1 69. Count number of key-value pairs in dictionary.
u={'Name': 'Sadhna', 'Weight': 64}
print(u.__len__())
# Out:
# 2

# %%
# 1 70. Check if a key exists in dictionary.
u={'Name': 'Sadhna', 'Weight': 64}
if not u :
    print("Not")
else:
    print("Yes")
# Out:
# Yes

# %%
# 1 71. Add a new key-value pair to dictionary.
u={'Name': 'Sadhna', 'Weight': 64}
u.update({"Age":42,"Gender":"F"})
print(u)
# Out:
# {'Name': 'Sadhna', 'Weight': 64, 'Age': 42, 'Gender': 'F'}

# %%
# 1 72. Merge two dictionaries.
u={'Name': 'Sadhna', 'Weight': 64}
v={"Class":"A","Married":"Yes"}
print(u | v)    #To merge two dict use "|"
# Out:
# {'Name': 'Sadhna', 'Weight': 64, 'Class': 'A', 'Married': 'Yes'}

# %%
# 1 73. Remove the last inserted item from dictionary.
u={'Name': 'Sadhna', 'Weight': 64}
p=u.popitem()
print(p)
# Out:
# ('Weight', 64)

# %%
# 1 74. Create a dictionary from a list of keys.
keys=["Na","Ag","Bgrp"]
value=["Suni",35,"B"]
di=dict(zip(keys,value))
print(di)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[266], line 4
#       2 keys=["Na","Ag","Bgrp"]
#       3 value=["Suni",35,"B"]
# ----> 4 di=dict(zip(keys,value))
#       5 print(di)
#
# TypeError: 'dict' object is not callable

# %%
# 1 75. Set default value for a dictionary key.
key=["Name","Age","Bgroup"]
dict2=dict.fromkeys(key,1)
print(dict2)
# Out:
# {'Name': 1, 'Age': 1, 'Bgroup': 1}

# %%
# 1 76. Print length of dictionary.
p={'Name': 1, 'Age': 1, 'Bgroup': 1}
print(p.__len__())
# Out:
# 3

# %%
# 1 77. Convert dictionary keys to a list.
print(keys)
# Out:
# ['Na', 'Ag', 'Bgrp']

# %%
# 1 78. Convert dictionary values to a list.
print(value)
# Out:
# ['Suni', 35, 'B']

# %%
# 1 79. Delete all items in dictionary. ###use delete not clear
print(p.clear())
# Out:
# None

# %%
# 1 80. Safely get a value using a dictionary method.

# %%
# 1 81. Add an element to a set.
se={3,2,4,5}
print(se.add("e"))
print(se)
# Out:
# None
# {2, 3, 4, 5, 'e'}

# %%
# 1 82. Remove an element from a set.
se.remove(5)
print(se)
# Out:
# {2, 3, 4, 'e'}

# %%
# 1 83. Remove an element from a set without error.
se={2, 3, 4, 'e'}
print(se.discard(4))
print(se)
# Out:
# None
# {2, 3, 'e'}

# %%
# 1 84. Clear a set.
se.clear()
print(se)
# Out:
# set()

# %%
# 1 85. Find union of two sets.
set1={1,3,5,2}
set2={5,8,7,9,6}
print(set1 | set2)
# Out:
# {1, 2, 3, 5, 6, 7, 8, 9}

# %%
# 1 86. Find intersection of two sets.
set1={1,3,5,2}
set2={5,8,7,9,6}
print(set1 or set2)
print(set.intersection(set1,set2))
# Out:
# {1, 2, 3, 5}
# {5}

# %%
# 1 87. Find difference of two sets.
a={8,6,9,7}
b={2,3,1,4,7}
w=a-b
x=a.difference(b)
# print(x)
print(w)
# Out:
# {8, 9, 6, 7}

# %%
# 1 88. Check if a set is subset of another set.
a={3,5,8,9,5,0}
s={3,5,5}
if s.issubset(a):
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
# 1 89. Copy a set.
a={3,5,8,9,5,0}
b=a.copy()
print(b)
# Out:
# {0, 3, 5, 8, 9}

# %%
# 1 90. Remove and print a random element from a set.
a={3,5,8,9,5,0}
m=a.pop()
print(m)
# Out:
# 0

# %%
# 1 91. Find maximum of three numbers.
a={3,5,8,9,5,0}
print(max(a))
# Out:
# 9

# %%
# 1 92. Find minimum element in a list.
print(min(a))
# Out:
# 3

# %%
# 1 93. Find sum of numbers in a list.
a={3,5,8,5,9,0}  #in sum it does not take duplicate values
print(sum(a))
# Out:
# 25

# %%
# 1 94. Count total elements using len().
print(len(a))
# Out:
# 5

# %%
# 1 95. Sort a list using sorted().
e=[3,2,5,4,6]
print(sorted(e))
# Out:
# [2, 3, 4, 5, 6]

# %%
# 1 96. Convert user input into integer.
i=int(input("enter number: "))
print(i)

# %%
# 1 97. Print type of a variable.
v="we"
print(type(v))
# Out:
# <class 'str'>

# %%
# 1 98. Generate numbers from 1 to 10 using range().
for i in range(1,10):
    print(i)

# %%
# 1 99. Pair two lists using zip().
l1=[2,3,5,4]
l2=[4,6,'t',7]
d=list(zip(l1,l2))
print(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[314], line 4
#       2 l1=[2,3,5,4]
#       3 l2=[4,6,'t',7]
# ----> 4 d=list(zip[l1,l2])
#       5 print(d)
#
# TypeError: type 'zip' is not subscriptable

# %%
# 1 100. Print index and value using enumerate().
l=[1,3,5,4,6]
for i, val in enumerate(l):
    print(i,val)
